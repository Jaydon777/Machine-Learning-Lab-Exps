# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd

# %%
df = pd.read_csv('Car_sales.csv')
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %% [markdown]
# ## X - independent 'Sales_in_thousands', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor'
# ## Y - dependent __year_resale_value

# %%
columns_of_interest = ['Sales_in_thousands', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 
                       'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor', '__year_resale_value']
df_cleaned = df.dropna(subset=columns_of_interest)

X = df_cleaned[['Sales_in_thousands', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 
                'Fuel_capacity', 'Fuel_efficiency', 'Power_perf_factor']]
Y = df_cleaned['__year_resale_value']

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_normalized,Y,test_size = 0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_

# %%
c
# Out:
# 13.121697510672206

# %%
m = lr.coef_
m
# Out:
# array([-7.09391532e-01,  3.96187027e+08,  2.55320627e+07,  1.95580789e+09,
#         4.01851869e+00,  1.86852112e+00, -7.79967520e+00, -1.55656222e+01,
#         6.05060530e+00, -6.63148901e+00, -2.30799912e+09])

# %%
y_pred_train = lr.predict(X_train)

# %%
y_pred_train
# Out:
# array([19.6640028 ,  7.22730818, 16.52037653,  7.87642839, 20.0511367 ,
#        37.02084741, 16.31526038, 17.49846515, 10.49043294, 16.97900709,
#        27.86153385, 35.29701349, 10.06134745, 13.29518887, 14.06221863,
#        18.46439847, 11.27735325, 21.41794356, 10.58828136, 24.9468697 ,
#         8.89863756, 10.15971431,  7.47688567,  9.27012118, 13.76249918,
#        47.48005494,  8.65283641, 14.00736644, 18.30023118, 16.85774168,
#        12.41888746,  9.7845247 , 20.74099192, 10.63944461, 13.54297658,
#        55.58673843, 13.17349299, 17.04010388,  9.88003233, 61.28290304,
#         8.85749122, 58.27714046, 20.12533173, 12.74683937, 13.99096307,
#        13.27754828, 14.251089  , 14.21131762, 15.03588202, 14.46477547,
#        52.90211495, 20.16560933, 63.57691749, 35.57738694, 14.46952298,
#        10.78109493, 23.69891032, 12.67442867,  8.00085839,  8.89606508,
#        34.37373158, 15.86389169, 16.85116776, 12.51154825, 14.40826001,
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_train, y_pred_train)
# Out:
# 0.9560532402093954

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
custom_input = pd.DataFrame({
    'Sales_in_thousands': [50],
    'Price_in_thousands': [20],
    'Engine_size': [3.0],
    'Horsepower': [200],
    'Wheelbase': [100],
    'Width': [60],
    'Length': [150],
    'Curb_weight': [3],
    'Fuel_capacity': [15],
    'Fuel_efficiency': [25],
    'Power_perf_factor': [50]
})

custom_prediction = lr.predict(scaler.fit_transform(custom_input))

# Output the predicted __year_resale_value for the custom input
print(f"The predicted __year_resale_value for the custom input is: {float(custom_prediction[0])}")
# Out:
# The predicted __year_resale_value for the custom input is: 13.121697510672206
